# %%
import pandas as a
import numpy as b
#variabel

# %%
df = a.read_csv('./Documents/KULIAH COK/visualisasi data/DATASET/titanicfull.csv')
df.head()
#manggil data dari file manager
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked
# 0  29.00      0      0   24160  211.3375       B5        S
# 1   0.92      1      2  113781  151.5500  C22 C26        S
# 2   2.00      1      2  113781  151.5500  C22 C26        S
# 3  30.00      1      2  113781  151.5500  C22 C26        S
# 4  25.00      1      2  113781  151.5500  C22 C26        S

# %%
df[(df['sex'] == 'female') & (df['age'] >= 60) & (df['embarked'] == 'S') & (df['survived'] == 1)]
#mengkategorikan data
# Out:
#       pclass  survived                                               name  \
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 83         1         1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 116        1         1                Fortune, Mrs. Mark (Mary McDougald)
# 1261       3         1                             Turkula, Mrs. (Hedwig)
#
#          sex   age  sibsp  parch  ticket      fare        cabin embarked
# 6     female  63.0      1      0   13502   77.9583           D7        S
# 61    female  76.0      1      0   19877   78.8500          C46        S
# 83    female  64.0      1      1  112901   26.5500          B26        S
# 116   female  60.0      1      4   19950  263.0000  C23 C25 C27        S
# 1261  female  63.0      0      0    4134    9.5875          NaN        S

# %%
df[
    (df['sex'] == 'female') &
    (df['age'] >=  60) &
    (df['embarked'] == 'S') &
    (df['survived'] == 1) 
]
#sama kaya diatas cmn dibikin rapih
# Out:
#       pclass  survived                                               name  \
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 83         1         1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 116        1         1                Fortune, Mrs. Mark (Mary McDougald)
# 1261       3         1                             Turkula, Mrs. (Hedwig)
#
#          sex   age  sibsp  parch  ticket      fare        cabin embarked
# 6     female  63.0      1      0   13502   77.9583           D7        S
# 61    female  76.0      1      0   19877   78.8500          C46        S
# 83    female  64.0      1      1  112901   26.5500          B26        S
# 116   female  60.0      1      4   19950  263.0000  C23 C25 C27        S
# 1261  female  63.0      0      0    4134    9.5875          NaN        S

# %%
kr1 = df['sex'] == 'female'
kr2 = df['age'] >= 60
kr3 = df['embarked'] == 'S'
kr4 = df['survived'] == 1
df[kr1 & kr2 & kr3 & kr4]
#sama kaya diatas 'God help us :)'
# Out:
#       pclass  survived                                               name  \
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 83         1         1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 116        1         1                Fortune, Mrs. Mark (Mary McDougald)
# 1261       3         1                             Turkula, Mrs. (Hedwig)
#
#          sex   age  sibsp  parch  ticket      fare        cabin embarked
# 6     female  63.0      1      0   13502   77.9583           D7        S
# 61    female  76.0      1      0   19877   78.8500          C46        S
# 83    female  64.0      1      1  112901   26.5500          B26        S
# 116   female  60.0      1      4   19950  263.0000  C23 C25 C27        S
# 1261  female  63.0      0      0    4134    9.5875          NaN        S

# %%
df = a.read_csv('./Documents/KULIAH COK/visualisasi data/DATASET/iris.csv')
df.head(8)
#menampilkan data dari file manager
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa

# %%
df = a.read_csv('./Documents/KULIAH COK/visualisasi data/DATASET/iris.csv', header = 2, skiprows = [5, 6])
df.head()
# Out:
#    2  4.9  3.0  1.4  0.2  Iris-setosa
# 0  3  4.7  3.2  1.3  0.2  Iris-setosa
# 1  4  4.6  3.1  1.5  0.2  Iris-setosa
# 2  7  4.6  3.4  1.4  0.3  Iris-setosa
# 3  8  5.0  3.4  1.5  0.2  Iris-setosa
# 4  9  4.4  2.9  1.4  0.2  Iris-setosa

# %%
n_row = 6
n_col = 5
col =tuple('ABCDE')
df = a.DataFrame(b.random.randint(1, 5, size = (n_row, n_col)),
                 columns = col)
df
#buat tabel
# Out:
#    A  B  C  D  E
# 0  1  2  2  4  1
# 1  1  4  4  2  1
# 2  4  1  1  4  3
# 3  2  4  3  3  1
# 4  2  4  3  1  3
# 5  3  1  2  4  1

# %%
df.sample(frac = 1.0, random_state = 1)
#ngacak baris
# Out:
#    A  B  C  D  E
# 2  4  1  1  4  3
# 1  1  4  4  2  1
# 4  2  4  3  1  3
# 0  1  2  2  4  1
# 3  2  4  3  3  1
# 5  3  1  2  4  1

# %%
df.sample(frac = 1.0, random_state = 1).reset_index(drop = True)
#buat tabel hasil acakan diatas jadi berbaris rapih tapi isi masi hasil acak
# Out:
#    A  B  C  D  E
# 0  4  1  1  4  3
# 1  1  4  4  2  1
# 2  2  4  3  1  3
# 3  1  2  2  4  1
# 4  2  4  3  3  1
# 5  3  1  2  4  1

# %%
df = a.read_csv('./Documents/KULIAH COK/visualisasi data/DATASET/titanicfull.csv')
df.head()
#manggil data dari file manager
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked
# 0  29.00      0      0   24160  211.3375       B5        S
# 1   0.92      1      2  113781  151.5500  C22 C26        S
# 2   2.00      1      2  113781  151.5500  C22 C26        S
# 3  30.00      1      2  113781  151.5500  C22 C26        S
# 4  25.00      1      2  113781  151.5500  C22 C26        S

# %%
grouped_df = df.groupby('sex')
#menentukan kategori

# %%
grouped_df.get_group('female').head(10)
#menentukan kategori sex female 10 baris
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 2        1         0                       Allison, Miss. Helen Loraine
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
#
#        sex   age  sibsp  parch    ticket      fare    cabin embarked
# 0   female  29.0      0      0     24160  211.3375       B5        S
# ...

# %%
grouped_df = df.groupby('survived')
#menentukan kategori

# %%
grouped_df.get_group(1).head(10)
#menentukan kategori survived 1 10 baris
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
#
#        sex    age  sibsp  parch    ticket      fare    cabin embarked
# 0   female  29.00      0      0     24160  211.3375       B5        S
# ...
